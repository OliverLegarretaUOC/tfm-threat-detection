# %% [markdown]
# # Notebook 28 — Evaluación Modelo D sobre dataset GAR
#
# **TFM — Sistema de Detección de Amenazas Armadas en Vídeo**
# Oliver Legarreta García · Universitat Oberta de Catalunya
#
# ---
#
# ## Objetivo
#
# Evaluar **Modelo C** (`yolov8m-seg`) sobre el dataset GAR con el mismo protocolo que Modelo B, para obtener la comparativa definitiva entre detección por bounding box y segmentación de instancias.
#
# ## Comparativa esperada
#
# | Modelo | Arquitectura | Task | mAP@50 (val) | F1 GAR | FP | FN |
# |--------|-------------|------|-------------|--------|-----|-----|
# | **B** | yolov8m | Detección | 0.7789 | 0.7949 | 48 | 16 |
# | **C** | yolov8m-seg | Segmentación | **0.9556** | ? | ? | ? |
#
# **Hipótesis:** Modelo C debería reducir FP en N6–N9 (teléfono) y N10–N11 (botella) gracias al aprendizaje de la forma exacta del arma mediante segmentación.
#
# **Dataset:** GAR test set — 140 clips positivos + 118 clips negativos
# **Modelo C:** `yolov8m_seg_C` · CONF=0.25 · Umbral clip=5 frames

# %% [markdown]
# ---
# ## 0. Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip -q install ultralytics opencv-python
print('✅ Dependencias instaladas')
# Out:
# ✅ Dependencias instaladas

# %%
import os
import json
import shutil
from pathlib import Path
from collections import defaultdict

import cv2
import numpy as np
from ultralytics import YOLO

# ── CONFIG ────────────────────────────────────────────────────────────────────
POS_LIST   = '/content/drive/MyDrive/TFM/datasets/videos/Gun_Action_Recognition_Dataset/splits/handgun_test.txt'
NEG_LIST   = '/content/drive/MyDrive/TFM/datasets/videos/Gun_Action_Recognition_Dataset/splits/no_gun_test.txt'
OUT_DIR = '/content/drive/MyDrive/TFM/experiments/video_tests/GAR/runs/evaluation_modelo_d'

# Pesos Modelo C
MODEL_C_WEIGHTS = '/content/drive/MyDrive/TFM/experiments/weapon_seg/yolov8m_seg_D/weights/best.pt'

IMG_SIZE            = 640
CONF_WEAPON         = 0.25
IOU_NMS             = 0.7
DETECTION_THRESHOLD = 5
MAX_SECONDS         = 15

CAT_LABELS = {
    'N1': 'Walking empty hands',  'N2': 'Jogging',
    'N3': 'Running',              'N4': 'Sneaking empty hands',
    'N5': 'Phone relaxed',        'N6': 'Phone looking',
    'N7': 'Phone both hands',     'N8': 'Phone recording 1h',
    'N9': 'Phone recording 2h',   'N10': 'Water bottle relaxed',
    'N11': 'Drinking',            'N12': 'Holding heavy object',
}

Path(OUT_DIR).mkdir(parents=True, exist_ok=True)

# Copiar pesos a /content/ para evitar desconexiones de Drive
# !cp '{MODEL_C_WEIGHTS}' /content/modelo_c_best.pt

# Cargar Modelo C
weapon_model = YOLO('/content/modelo_c_best.pt')

print('✅ Config cargada')
print(f'   Modelo C: yolov8m-seg')
print(f'   CONF:     {CONF_WEAPON}')
print(f'   Umbral:   {DETECTION_THRESHOLD} frames')
# Out:
# ✅ Config cargada
#    Modelo C: yolov8m-seg
#    CONF:     0.25
#    Umbral:   5 frames

# %% [markdown]
# ---
# ## 1. Funciones auxiliares

# %%
def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0]); yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2]); yB = min(boxA[3], boxB[3])
    inter = max(0, xB - xA) * max(0, yB - yA)
    if inter == 0: return 0.0
    aA = (boxA[2]-boxA[0]) * (boxA[3]-boxA[1])
    aB = (boxB[2]-boxB[0]) * (boxB[3]-boxB[1])
    return inter / (aA + aB - inter)


def load_gt_boxes(label_json_path):
    with open(label_json_path) as f:
        data = json.load(f)
    gt = defaultdict(list)
    for ann in data['annotations']:
        x, y, w, h = ann['bbox']
        gt[ann['image_id']].append((x, y, x+w, y+h))
    return gt


def run_detector_on_video(video_path):
    """
    Ejecuta Modelo C frame a frame.
    Devuelve lista de (frame_idx, preds) donde preds = [(x1,y1,x2,y2,conf),...]
    Nota: yolov8m-seg devuelve tanto boxes como masks — usamos solo boxes para
    mantener el mismo protocolo de evaluación que Modelo B.
    """
    cap = cv2.VideoCapture(str(video_path))
    fps = cap.get(cv2.CAP_PROP_FPS)
    n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    max_frames = n_frames
    if MAX_SECONDS and fps > 0:
        max_frames = min(max_frames, int(MAX_SECONDS * fps))

    results = []
    frame_i = 0
    while True:
        ok, frame = cap.read()
        if not ok or frame_i >= max_frames:
            break

        r = weapon_model.predict(
            frame, imgsz=IMG_SIZE, conf=CONF_WEAPON,
            iou=IOU_NMS, verbose=False, device='cuda'
        )[0]

        preds = []
        if r.boxes is not None and len(r.boxes) > 0:
            for b in r.boxes:
                x1, y1, x2, y2 = map(float, b.xyxy[0])
                conf = float(b.conf[0])
                preds.append((x1, y1, x2, y2, conf))
        results.append((frame_i + 1, preds))
        frame_i += 1

    cap.release()
    return results, max_frames


print('✅ Funciones auxiliares definidas')
# Out:
# ✅ Funciones auxiliares definidas

# %% [markdown]
# ---
# ## 2. BLOQUE A — mAP a nivel de frame

# %%
IOU_THRESHOLDS = np.arange(0.5, 1.0, 0.05)
all_tp = defaultdict(list)
all_fp = defaultdict(list)
total_gt = 0

print('\n' + '='*60)
print('BLOQUE A — mAP a nivel de frame (Modelo C)')
print('='*60)

pos_paths = [Path(l.strip()) for l in Path(POS_LIST).read_text().splitlines() if l.strip()]

for vp in pos_paths:
    if not vp.exists(): continue
    label_path = vp.parent / 'label.json'
    if not label_path.exists(): continue

    clip_id  = vp.parent.name
    local_in = f'/content/{clip_id}_eval.mp4'
    shutil.copy2(str(vp), local_in)

    gt_boxes = load_gt_boxes(label_path)
    total_gt += sum(len(v) for v in gt_boxes.values())

    frame_results, _ = run_detector_on_video(local_in)

    for (frame_idx, preds) in frame_results:
        gts = gt_boxes.get(frame_idx, [])
        for iou_thr in IOU_THRESHOLDS:
            matched_gt = set()
            for (px1, py1, px2, py2, conf) in sorted(preds, key=lambda x: -x[4]):
                best_iou, best_j = 0, -1
                for j, gt in enumerate(gts):
                    if j in matched_gt: continue
                    s = iou((px1, py1, px2, py2), gt)
                    if s > best_iou:
                        best_iou, best_j = s, j
                if best_iou >= iou_thr and best_j >= 0:
                    all_tp[iou_thr].append(1); all_fp[iou_thr].append(0)
                    matched_gt.add(best_j)
                else:
                    all_tp[iou_thr].append(0); all_fp[iou_thr].append(1)

    os.remove(local_in)
    print(f'  ✅ {clip_id}')

aps = {}
for iou_thr in IOU_THRESHOLDS:
    tp = sum(all_tp[iou_thr])
    fp = sum(all_fp[iou_thr])
    fn = total_gt - tp
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall    = tp / (tp + fn) if (tp + fn) > 0 else 0
    aps[iou_thr] = {'precision': precision, 'recall': recall}

map50   = aps[0.5]['precision']
map5095 = np.mean([v['precision'] for v in aps.values()])

print(f'\n  Total GT boxes  : {total_gt}')
print(f'  mAP@50          : {map50:.4f}')
print(f'  mAP@50:95       : {map5095:.4f}')
print(f'  Precision@50    : {aps[0.5]["precision"]:.4f}')
print(f'  Recall@50       : {aps[0.5]["recall"]:.4f}')
# Out:
# ============================================================
# BLOQUE A — mAP a nivel de frame (Modelo C)
# ============================================================
#   ✅ PAH1_C1_P1_V1_HB_3
#   ✅ PAH1_C1_P1_V1_HB_4
#   ✅ PAH1_C1_P2_V1_HB_1
#   ✅ PAH1_C1_P2_V1_HB_3
#   ✅ PAH1_C1_P4_V1_HB_1
#   ✅ PAH1_C1_P4_V1_HB_2
#   ✅ PAH1_C2_P3_V1_HB_1
#   ✅ PAH1_C2_P3_V1_HB_3
#   ✅ PAH1_C2_P3_V2_HB_2
#   ✅ PAH1_C2_P3_V2_HB_3
#   ✅ PAH1_C2_P5_V1_HB_1
#   ✅ PAH1_C2_P5_V1_HB_4
#   ✅ PAH1_C2_P5_V2_HB_3
#   ✅ PAH1_C2_P5_V2_HB_4
#   ✅ PAH2_C1_P1_V1_HB_1
#   ✅ PAH2_C1_P1_V1_HB_4
#   ✅ PAH2_C1_P2_V1_HB_3
#   ✅ PAH2_C1_P2_V1_HB_4
#   ✅ PAH2_C1_P4_V1_HB_1
#   ✅ PAH2_C1_P4_V1_HB_3
#   ✅ PAH2_C2_P3_V1_HB_1
#   ✅ PAH2_C2_P3_V1_HB_4
#   ✅ PAH2_C2_P3_V2_HB_2
#   ✅ PAH2_C2_P3_V2_HB_4
#   ✅ PAH2_C2_P5_V1_HB_3
#   ✅ PAH2_C2_P5_V1_HB_4
#   ✅ PAH2_C2_P5_V2_HB_2
#   ✅ PAH2_C2_P5_V2_HB_4
#   ✅ PAH3_C1_P1_V1_HB_1
#   ✅ PAH3_C1_P1_V1_HB_4
#   ✅ PAH3_C1_P2_V1_HB_1
#   ✅ PAH3_C1_P2_V1_HB_2
#   ✅ PAH3_C1_P4_V1_HB_2
#   ✅ PAH3_C1_P4_V1_HB_4
#   ✅ PAH3_C2_P3_V1_HB_1
#   ✅ PAH3_C2_P3_V1_HB_2
#   ✅ PAH3_C2_P3_V2_HB_1
#   ✅ PAH3_C2_P3_V2_HB_3
#   ✅ PAH3_C2_P5_V1_HB_2
#   ✅ PAH3_C2_P5_V1_HB_4
#   ✅ PAH3_C2_P5_V2_HB_2
#   ✅ PAH3_C2_P5_V2_HB_4
#   ✅ PAH4_C1_P2_V1_HB_2
#   ✅ PAH4_C1_P2_V1_HB_3
#   ✅ PAH4_C1_P4_V1_HB_1
#   ✅ PAH4_C2_P3_V1_HB_1
#   ✅ PAH4_C2_P3_V1_HB_4
#   ✅ PAH4_C2_P3_V2_HB_3
#   ✅ PAH4_C2_P3_V2_HB_4
#   ✅ PAH4_C2_P5_V1_HB_1
#   ✅ PAH4_C2_P5_V1_HB_3
#   ✅ PAH4_C2_P5_V2_HB_1
#   ✅ PAH4_C2_P5_V2_HB_2
#   ✅ PAH5_C1_P1_V1_HB_2
#   ✅ PAH5_C1_P2_V1_HB_1
#   ✅ PAH5_C1_P4_V1_HB_2
#   ✅ PAH5_C2_P3_V1_HB_2
#   ✅ PAH5_C2_P3_V2_HB_1
#   ✅ PAH5_C2_P5_V1_HB_2
#   ✅ PAH5_C2_P5_V2_HB_1
#   ✅ PAH6_C1_P1_V1_HB_2
#   ✅ PAH6_C1_P2_V1_HB_2
#   ✅ PAH6_C1_P4_V1_HB_1
#   ✅ PAH6_C2_P3_V1_HB_1
#   ✅ PAH6_C2_P3_V2_HB_1
#   ✅ PAH6_C2_P5_V1_HB_1
#   ✅ PAH6_C2_P5_V2_HB_1
#   ✅ PAH7_C1_P1_V1_HB_2
#   ✅ PAH7_C1_P2_V1_HB_1
#   ✅ PAH7_C2_P3_V1_HB_2
#   ✅ PAH7_C2_P3_V2_HB_1
#   ✅ PAH7_C2_P5_V1_HB_2
#   ✅ PAH7_C2_P5_V2_HB_1
#   ✅ PAH8_C1_P1_V1_HB_1
#   ✅ PAH8_C1_P2_V1_HB_2
#   ✅ PAH8_C1_P4_V1_HB_2
#   ✅ PAH8_C2_P3_V1_HB_1
#   ✅ PAH8_C2_P3_V2_HB_1
#   ✅ PAH8_C2_P5_V1_HB_1
#   ✅ PAH8_C2_P5_V2_HB_2
#   ✅ PAH9_C1_P4_V1_HB_1
#   ✅ PAH9_C2_P3_V1_HB_2
#   ✅ PAH9_C2_P3_V2_HB_2
#   ✅ PAH9_C2_P5_V1_HB_2
#   ✅ PAH9_C2_P5_V1_HB_4
#   ✅ PAH9_C2_P5_V2_HB_1
#   ✅ PCH1_C1_P1_V1_HB_1
#   ✅ PCH1_C1_P2_V1_HB_2
#   ✅ PCH1_C1_P2_V1_HB_4
#   ✅ PCH1_C1_P4_V1_HB_2
#   ✅ PCH1_C1_P4_V1_HB_4
#   ✅ PCH1_C2_P3_V1_HB_1
#   ✅ PCH1_C2_P3_V1_HB_2
#   ✅ PCH1_C2_P3_V2_HB_2
#   ✅ PCH1_C2_P3_V2_HB_3
#   ✅ PCH1_C2_P5_V1_HB_2
#   ✅ PCH1_C2_P5_V1_HB_4
#   ✅ PCH1_C2_P5_V2_HB_2
#   ✅ PCH1_C2_P5_V2_HB_4
#   ✅ PCH2_C1_P1_V1_HB_1
#   ✅ PCH2_C1_P2_V1_HB_2
#   ✅ PCH2_C1_P4_V1_HB_2
#   ✅ PCH2_C2_P3_V1_HB_2
#   ✅ PCH2_C2_P3_V2_HB_1
#   ✅ PCH2_C2_P5_V1_HB_2
#   ✅ PCH2_C2_P5_V2_HB_2
#   ✅ PCH3_C1_P1_V1_HB_1
#   ✅ PCH3_C1_P2_V1_HB_1
#   ✅ PCH3_C1_P4_V1_HB_1
#   ✅ PCH3_C2_P3_V1_HB_1
#   ✅ PCH3_C2_P3_V2_HB_1
#   ✅ PCH3_C2_P5_V1_HB_1
#   ✅ PCH3_C2_P5_V2_HB_1
#   ✅ PCH4_C1_P1_V1_HB_1
#   ✅ PCH4_C1_P2_V1_HB_2
#   ✅ PCH4_C1_P4_V1_HB_2
#   ✅ PCH4_C2_P3_V1_HB_1
#   ✅ PCH4_C2_P3_V2_HB_1
#   ✅ PCH4_C2_P5_V1_HB_2
#   ✅ PCH4_C2_P5_V2_HB_2
#   ✅ PCH5_C1_P2_V1_HB_1
#   ✅ PCH5_C1_P4_V1_HB_2
#   ✅ PCH5_C2_P3_V1_HB_1
#   ✅ PCH5_C2_P3_V2_HB_1
#   ✅ PCH5_C2_P5_V1_HB_2
#   ✅ PCH5_C2_P5_V2_HB_2
#   ✅ PCH6_C1_P1_V1_HB_1
#   ✅ PCH6_C1_P2_V1_HB_2
#   ✅ PCH6_C1_P4_V1_HB_2
#   ✅ PCH6_C2_P3_V1_HB_2
#   ✅ PCH6_C2_P3_V2_HB_2
#   ✅ PCH6_C2_P5_V1_HB_1
#   ✅ PCH6_C2_P5_V2_HB_1
#   ✅ PCH7_C1_P1_V1_HB_2
#   ✅ PCH7_C1_P2_V1_HB_1
#   ✅ PCH7_C1_P4_V1_HB_2
#   ✅ PCH7_C2_P3_V1_HB_2
#   ✅ PCH7_C2_P3_V2_HB_2
#   ✅ PCH7_C2_P5_V1_HB_2
#   ✅ PCH7_C2_P5_V2_HB_2
#
#   Total GT boxes  : 20545
#   mAP@50          : 0.0457
#   mAP@50:95       : 0.0098
#   Precision@50    : 0.0457
#   Recall@50       : 0.0447

# %% [markdown]
# ---
# ## 3. BLOQUE B — Clasificación a nivel de clip

# %%
print('\n' + '='*60)
print(f'BLOQUE B — Clasificación clip-level (umbral={DETECTION_THRESHOLD} frames)')
print('='*60)

y_true, y_pred = [], []
clip_details   = []

def classify_clip(video_path):
    local_in = '/content/tmp_cls.mp4'
    shutil.copy2(str(video_path), local_in)
    frame_results, n_total = run_detector_on_video(local_in)
    os.remove(local_in)
    frames_with_gun = sum(1 for (_, preds) in frame_results if len(preds) > 0)
    pred = 1 if frames_with_gun >= DETECTION_THRESHOLD else 0
    return pred, frames_with_gun, n_total

# Positivos
print('\n  Procesando positivos...')
for vp in pos_paths:
    if not vp.exists(): continue
    clip_id = vp.parent.name
    pred, n_det, n_total = classify_clip(vp)
    y_true.append(1); y_pred.append(pred)
    clip_details.append({'clip': clip_id, 'true': 1, 'pred': pred,
                         'det_frames': n_det, 'total_frames': n_total,
                         'category': 'POS'})
    print(f'    {clip_id}: {n_det}/{n_total} frames → {"✅TP" if pred==1 else "❌FN"}')

# Negativos
neg_paths = [Path(l.strip()) for l in Path(NEG_LIST).read_text().splitlines() if l.strip()]
print(f'\n  Procesando negativos ({len(neg_paths)} clips)...')
for vp in neg_paths:
    if not vp.exists(): continue
    clip_id  = vp.parent.name
    category = clip_id.split('_')[0]
    pred, n_det, n_total = classify_clip(vp)
    y_true.append(0); y_pred.append(pred)
    clip_details.append({'clip': clip_id, 'true': 0, 'pred': pred,
                         'det_frames': n_det, 'total_frames': n_total,
                         'category': category})
    print(f'    {clip_id}: {n_det}/{n_total} frames → {"❌FP" if pred==1 else "✅TN"}')

# Métricas globales
y_true = np.array(y_true)
y_pred = np.array(y_pred)

TP = int(((y_true==1) & (y_pred==1)).sum())
TN = int(((y_true==0) & (y_pred==0)).sum())
FP = int(((y_true==0) & (y_pred==1)).sum())
FN = int(((y_true==1) & (y_pred==0)).sum())

accuracy  = (TP + TN) / len(y_true)
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall    = TP / (TP + FN) if (TP + FN) > 0 else 0
f1        = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

print(f'\n  --- Métricas globales (clip-level) ---')
print(f'  Clips evaluados : {len(y_true)} ({TP+FN} pos / {TN+FP} neg)')
print(f'  Accuracy        : {accuracy:.4f}')
print(f'  Precision       : {precision:.4f}')
print(f'  Recall          : {recall:.4f}')
print(f'  F1              : {f1:.4f}')
print(f'\n  Matriz de confusión:')
print(f'                Pred POS   Pred NEG')
print(f'  Real POS    |   {TP:4d}   |   {FN:4d}  |')
print(f'  Real NEG    |   {FP:4d}   |   {TN:4d}  |')
# Out:
# ============================================================
# BLOQUE B — Clasificación clip-level (umbral=5 frames)
# ============================================================
#
#   Procesando positivos...
#     PAH1_C1_P1_V1_HB_3: 0/150 frames → ❌FN
#     PAH1_C1_P1_V1_HB_4: 7/175 frames → ✅TP
#     PAH1_C1_P2_V1_HB_1: 75/275 frames → ✅TP
#     PAH1_C1_P2_V1_HB_3: 26/225 frames → ✅TP
#     PAH1_C1_P4_V1_HB_1: 87/150 frames → ✅TP
#     PAH1_C1_P4_V1_HB_2: 67/150 frames → ✅TP
#     PAH1_C2_P3_V1_HB_1: 258/270 frames → ✅TP
#     PAH1_C2_P3_V1_HB_3: 269/270 frames → ✅TP
#     PAH1_C2_P3_V2_HB_2: 329/330 frames → ✅TP
#     PAH1_C2_P3_V2_HB_3: 283/300 frames → ✅TP
#     PAH1_C2_P5_V1_HB_1: 123/240 frames → ✅TP
#     PAH1_C2_P5_V1_HB_4: 144/270 frames → ✅TP
#     PAH1_C2_P5_V2_HB_3: 138/270 frames → ✅TP
#     PAH1_C2_P5_V2_HB_4: 132/270 frames → ✅TP
#     PAH2_C1_P1_V1_HB_1: 2/175 frames → ❌FN
#     PAH2_C1_P1_V1_HB_4: 14/200 frames → ✅TP
#     PAH2_C1_P2_V1_HB_3: 97/275 frames → ✅TP
#     PAH2_C1_P2_V1_HB_4: 0/250 frames → ❌FN
#     PAH2_C1_P4_V1_HB_1: 77/175 frames → ✅TP
#     PAH2_C1_P4_V1_HB_3: 50/150 frames → ✅TP
#     PAH2_C2_P3_V1_HB_1: 234/240 frames → ✅TP
#     PAH2_C2_P3_V1_HB_4: 240/240 frames → ✅TP
#     PAH2_C2_P3_V2_HB_2: 298/300 frames → ✅TP
#     PAH2_C2_P3_V2_HB_4: 299/300 frames → ✅TP
#     PAH2_C2_P5_V1_HB_3: 176/300 frames → ✅TP
#     PAH2_C2_P5_V1_HB_4: 180/330 frames → ✅TP
#     PAH2_C2_P5_V2_HB_2: 171/300 frames → ✅TP
#     PAH2_C2_P5_V2_HB_4: 162/300 frames → ✅TP
#     PAH3_C1_P1_V1_HB_1: 24/200 frames → ✅TP
#     PAH3_C1_P1_V1_HB_4: 5/200 frames → ✅TP
#     PAH3_C1_P2_V1_HB_1: 40/275 frames → ✅TP
#     PAH3_C1_P2_V1_HB_2: 2/250 frames → ❌FN
#     PAH3_C1_P4_V1_HB_2: 64/175 frames → ✅TP
#     PAH3_C1_P4_V1_HB_4: 33/150 frames → ✅TP
#     PAH3_C2_P3_V1_HB_1: 266/270 frames → ✅TP
#     PAH3_C2_P3_V1_HB_2: 270/270 frames → ✅TP
#     PAH3_C2_P3_V2_HB_1: 262/270 frames → ✅TP
#     PAH3_C2_P3_V2_HB_3: 265/270 frames → ✅TP
#     PAH3_C2_P5_V1_HB_2: 145/270 frames → ✅TP
#     PAH3_C2_P5_V1_HB_4: 113/270 frames → ✅TP
#     PAH3_C2_P5_V2_HB_2: 149/270 frames → ✅TP
#     PAH3_C2_P5_V2_HB_4: 110/270 frames → ✅TP
#     PAH4_C1_P2_V1_HB_2: 0/250 frames → ❌FN
#     PAH4_C1_P2_V1_HB_3: 6/275 frames → ✅TP
#     PAH4_C1_P4_V1_HB_1: 47/175 frames → ✅TP
#     PAH4_C2_P3_V1_HB_1: 269/270 frames → ✅TP
#     PAH4_C2_P3_V1_HB_4: 239/240 frames → ✅TP
#     PAH4_C2_P3_V2_HB_3: 261/270 frames → ✅TP
#     PAH4_C2_P3_V2_HB_4: 300/300 frames → ✅TP
#     PAH4_C2_P5_V1_HB_1: 153/270 frames → ✅TP
#     PAH4_C2_P5_V1_HB_3: 147/270 frames → ✅TP
#     PAH4_C2_P5_V2_HB_1: 157/270 frames → ✅TP
#     PAH4_C2_P5_V2_HB_2: 175/270 frames → ✅TP
#     PAH5_C1_P1_V1_HB_2: 15/200 frames → ✅TP
#     PAH5_C1_P2_V1_HB_1: 95/275 frames → ✅TP
#     PAH5_C1_P4_V1_HB_2: 67/175 frames → ✅TP
#     PAH5_C2_P3_V1_HB_2: 300/300 frames → ✅TP
#     PAH5_C2_P3_V2_HB_1: 300/300 frames → ✅TP
#     PAH5_C2_P5_V1_HB_2: 204/300 frames → ✅TP
#     PAH5_C2_P5_V2_HB_1: 172/270 frames → ✅TP
#     PAH6_C1_P1_V1_HB_2: 9/175 frames → ✅TP
#     PAH6_C1_P2_V1_HB_2: 0/250 frames → ❌FN
#     PAH6_C1_P4_V1_HB_1: 71/200 frames → ✅TP
#     PAH6_C2_P3_V1_HB_1: 268/270 frames → ✅TP
#     PAH6_C2_P3_V2_HB_1: 317/330 frames → ✅TP
#     PAH6_C2_P5_V1_HB_1: 113/270 frames → ✅TP
#     PAH6_C2_P5_V2_HB_1: 125/270 frames → ✅TP
#     PAH7_C1_P1_V1_HB_2: 16/200 frames → ✅TP
#     PAH7_C1_P2_V1_HB_1: 88/300 frames → ✅TP
#     PAH7_C2_P3_V1_HB_2: 237/240 frames → ✅TP
#     PAH7_C2_P3_V2_HB_1: 270/270 frames → ✅TP
#     PAH7_C2_P5_V1_HB_2: 158/300 frames → ✅TP
#     PAH7_C2_P5_V2_HB_1: 208/300 frames → ✅TP
#     PAH8_C1_P1_V1_HB_1: 12/200 frames → ✅TP
#     PAH8_C1_P2_V1_HB_2: 0/225 frames → ❌FN
#     PAH8_C1_P4_V1_HB_2: 86/175 frames → ✅TP
#     PAH8_C2_P3_V1_HB_1: 240/240 frames → ✅TP
#     PAH8_C2_P3_V2_HB_1: 299/300 frames → ✅TP
#     PAH8_C2_P5_V1_HB_1: 195/300 frames → ✅TP
#     PAH8_C2_P5_V2_HB_2: 202/330 frames → ✅TP
#     PAH9_C1_P4_V1_HB_1: 81/175 frames → ✅TP
#     PAH9_C2_P3_V1_HB_2: 295/300 frames → ✅TP
#     PAH9_C2_P3_V2_HB_2: 295/300 frames → ✅TP
#     PAH9_C2_P5_V1_HB_2: 161/300 frames → ✅TP
#     PAH9_C2_P5_V1_HB_4: 73/270 frames → ✅TP
#     PAH9_C2_P5_V2_HB_1: 227/330 frames → ✅TP
#     PCH1_C1_P1_V1_HB_1: 6/150 frames → ✅TP
#     PCH1_C1_P2_V1_HB_2: 3/225 frames → ❌FN
#     PCH1_C1_P2_V1_HB_4: 1/225 frames → ❌FN
#     PCH1_C1_P4_V1_HB_2: 85/125 frames → ✅TP
#     PCH1_C1_P4_V1_HB_4: 66/150 frames → ✅TP
#     PCH1_C2_P3_V1_HB_1: 225/240 frames → ✅TP
#     PCH1_C2_P3_V1_HB_2: 263/270 frames → ✅TP
#     PCH1_C2_P3_V2_HB_2: 189/210 frames → ✅TP
#     PCH1_C2_P3_V2_HB_3: 256/270 frames → ✅TP
#     PCH1_C2_P5_V1_HB_2: 96/300 frames → ✅TP
#     PCH1_C2_P5_V1_HB_4: 2/270 frames → ❌FN
#     PCH1_C2_P5_V2_HB_2: 45/270 frames → ✅TP
#     PCH1_C2_P5_V2_HB_4: 44/270 frames → ✅TP
#     PCH2_C1_P1_V1_HB_1: 2/200 frames → ❌FN
#     PCH2_C1_P2_V1_HB_2: 14/225 frames → ✅TP
#     PCH2_C1_P4_V1_HB_2: 75/150 frames → ✅TP
#     PCH2_C2_P3_V1_HB_2: 222/240 frames → ✅TP
#     PCH2_C2_P3_V2_HB_1: 246/270 frames → ✅TP
#     PCH2_C2_P5_V1_HB_2: 105/300 frames → ✅TP
#     PCH2_C2_P5_V2_HB_2: 89/270 frames → ✅TP
#     PCH3_C1_P1_V1_HB_1: 1/175 frames → ❌FN
#     PCH3_C1_P2_V1_HB_1: 25/250 frames → ✅TP
#     PCH3_C1_P4_V1_HB_1: 43/125 frames → ✅TP
#     PCH3_C2_P3_V1_HB_1: 195/210 frames → ✅TP
#     PCH3_C2_P3_V2_HB_1: 281/300 frames → ✅TP
#     PCH3_C2_P5_V1_HB_1: 33/240 frames → ✅TP
#     PCH3_C2_P5_V2_HB_1: 35/270 frames → ✅TP
#     PCH4_C1_P1_V1_HB_1: 2/225 frames → ❌FN
#     PCH4_C1_P2_V1_HB_2: 30/225 frames → ✅TP
#     PCH4_C1_P4_V1_HB_2: 59/150 frames → ✅TP
#     PCH4_C2_P3_V1_HB_1: 282/300 frames → ✅TP
#     PCH4_C2_P3_V2_HB_1: 235/270 frames → ✅TP
#     PCH4_C2_P5_V1_HB_2: 143/300 frames → ✅TP
#     PCH4_C2_P5_V2_HB_2: 137/300 frames → ✅TP
#     PCH5_C1_P2_V1_HB_1: 56/250 frames → ✅TP
#     PCH5_C1_P4_V1_HB_2: 34/125 frames → ✅TP
#     PCH5_C2_P3_V1_HB_1: 253/270 frames → ✅TP
#     PCH5_C2_P3_V2_HB_1: 251/270 frames → ✅TP
#     PCH5_C2_P5_V1_HB_2: 92/300 frames → ✅TP
#     PCH5_C2_P5_V2_HB_2: 60/330 frames → ✅TP
#     PCH6_C1_P1_V1_HB_1: 10/225 frames → ✅TP
#     PCH6_C1_P2_V1_HB_2: 81/225 frames → ✅TP
#     PCH6_C1_P4_V1_HB_2: 66/150 frames → ✅TP
#     PCH6_C2_P3_V1_HB_2: 279/300 frames → ✅TP
#     PCH6_C2_P3_V2_HB_2: 248/270 frames → ✅TP
#     PCH6_C2_P5_V1_HB_1: 165/300 frames → ✅TP
#     PCH6_C2_P5_V2_HB_1: 122/300 frames → ✅TP
#     PCH7_C1_P1_V1_HB_2: 3/175 frames → ❌FN
#     PCH7_C1_P2_V1_HB_1: 13/275 frames → ✅TP
#     PCH7_C1_P4_V1_HB_2: 50/150 frames → ✅TP
#     PCH7_C2_P3_V1_HB_2: 279/300 frames → ✅TP
#     PCH7_C2_P3_V2_HB_2: 232/240 frames → ✅TP
#     PCH7_C2_P5_V1_HB_2: 77/300 frames → ✅TP
#     PCH7_C2_P5_V2_HB_2: 133/300 frames → ✅TP
#
#   Procesando negativos (118 clips)...
#     N10_C1_P1_V1_HB_1: 0/175 frames → ✅TN
#     N10_C1_P2_V1_HB_1: 0/250 frames → ✅TN
#     N10_C1_P4_V1_HB_2: 27/150 frames → ❌FP
#     N10_C2_P3_V1_HB_2: 270/270 frames → ❌FP
#     N10_C2_P3_V2_HB_2: 210/210 frames → ❌FP
#     N10_C2_P5_V1_HB_1: 26/270 frames → ❌FP
#     N10_C2_P5_V2_HB_1: 9/270 frames → ❌FP
#     N10_C2_P5_V3_HB_1: 21/270 frames → ❌FP
#     N10_C2_P5_V4_HB_2: 28/300 frames → ❌FP
#     N11_C1_P1_V1_HB_1: 0/200 frames → ✅TN
#     N11_C1_P2_V1_HB_2: 6/225 frames → ❌FP
#     N11_C1_P4_V1_HB_2: 29/150 frames → ❌FP
#     N11_C2_P3_V1_HB_2: 262/270 frames → ❌FP
#     N11_C2_P3_V2_HB_2: 267/270 frames → ❌FP
#     N11_C2_P5_V1_HB_2: 5/300 frames → ❌FP
#     N11_C2_P5_V2_HB_1: 12/270 frames → ❌FP
#     N11_C2_P5_V3_HB_1: 37/450 frames → ❌FP
#     N11_C2_P5_V4_HB_1: 27/240 frames → ❌FP
#     N12_C1_P1_V1_HB_1: 0/225 frames → ✅TN
#     N12_C1_P2_V1_HB_1: 0/200 frames → ✅TN
#     N12_C1_P2_V1_HB_2: 0/200 frames → ✅TN
#     N12_C1_P4_V1_HB_1: 14/150 frames → ❌FP
#     N12_C2_P3_V1_HB_2: 147/240 frames → ❌FP
#     N12_C2_P5_V1_HB_1: 5/270 frames → ❌FP
#     N12_C2_P5_V2_HB_2: 2/240 frames → ✅TN
#     N12_C2_P5_V2_HB_3: 63/270 frames → ❌FP
#     N12_C2_P5_V3_HB_1: 11/270 frames → ❌FP
#     N12_C2_P5_V4_HB_2: 40/270 frames → ❌FP
#     N1_C1_P1_V1_HB_1: 0/175 frames → ✅TN
#     N1_C1_P2_V1_HB_1: 0/200 frames → ✅TN
#     N1_C1_P4_V1_HB_1: 21/150 frames → ❌FP
#     N1_C2_P3_V1_HB_2: 235/240 frames → ❌FP
#     N1_C2_P3_V2_HB_1: 267/270 frames → ❌FP
#     N1_C2_P5_V1_HB_1: 142/240 frames → ❌FP
#     N1_C2_P5_V2_HB_1: 93/240 frames → ❌FP
#     N1_C2_P5_V3_HB_2: 26/360 frames → ❌FP
#     N1_C2_P5_V4_HB_2: 12/270 frames → ❌FP
#     N2_C1_P1_V1_HB_1: 0/125 frames → ✅TN
#     N2_C1_P2_V1_HB_1: 3/250 frames → ✅TN
#     N2_C1_P4_V1_HB_2: 9/125 frames → ❌FP
#     N2_C2_P3_V1_HB_2: 208/210 frames → ❌FP
#     N2_C2_P3_V2_HB_1: 204/210 frames → ❌FP
#     N2_C2_P5_V1_HB_1: 6/210 frames → ❌FP
#     N2_C2_P5_V2_HB_1: 11/240 frames → ❌FP
#     N2_C2_P5_V3_HB_2: 13/240 frames → ❌FP
#     N2_C2_P5_V4_HB_2: 15/240 frames → ❌FP
#     N3_C1_P1_V1_HB_1: 0/125 frames → ✅TN
#     N3_C1_P2_V1_HB_2: 0/175 frames → ✅TN
#     N3_C2_P3_V1_HB_1: 209/210 frames → ❌FP
#     N3_C2_P3_V2_HB_1: 210/210 frames → ❌FP
#     N3_C2_P5_V1_HB_1: 7/210 frames → ❌FP
#     N3_C2_P5_V2_HB_1: 5/180 frames → ❌FP
#     N3_C2_P5_V3_HB_1: 7/180 frames → ❌FP
#     N3_C2_P5_V4_HB_1: 5/210 frames → ❌FP
#     N4_C1_P1_V1_HB_1: 0/200 frames → ✅TN
#     N4_C1_P2_V1_HB_1: 0/250 frames → ✅TN
#     N4_C1_P4_V1_HB_1: 48/150 frames → ❌FP
#     N4_C2_P3_V1_HB_2: 237/240 frames → ❌FP
#     N4_C2_P3_V2_HB_1: 210/210 frames → ❌FP
#     N4_C2_P5_V1_HB_1: 26/270 frames → ❌FP
#     N4_C2_P5_V2_HB_1: 6/270 frames → ❌FP
#     N5_C1_P1_V1_HB_2: 6/200 frames → ❌FP
#     N5_C1_P2_V1_HB_1: 0/250 frames → ✅TN
#     N5_C1_P4_V1_HB_2: 12/150 frames → ❌FP
#     N5_C1_P4_V1_HB_4: 55/175 frames → ❌FP
#     N5_C2_P5_V1_HB_1: 33/300 frames → ❌FP
#     N5_C2_P5_V1_HB_3: 39/270 frames → ❌FP
#     N5_C2_P5_V2_HB_1: 9/270 frames → ❌FP
#     N5_C2_P5_V2_HB_4: 13/270 frames → ❌FP
#     N5_C2_P5_V3_HB_1: 31/300 frames → ❌FP
#     N5_C2_P5_V4_HB_2: 9/270 frames → ❌FP
#     N6_C1_P1_V1_HB_2: 11/175 frames → ❌FP
#     N6_C1_P1_V1_HB_3: 2/200 frames → ✅TN
#     N6_C1_P2_V1_HB_2: 0/200 frames → ✅TN
#     N6_C1_P2_V1_HB_4: 0/225 frames → ✅TN
#     N6_C1_P4_V1_HB_1: 60/175 frames → ❌FP
#     N6_C1_P4_V1_HB_4: 95/175 frames → ❌FP
#     N6_C2_P3_V1_HB_1: 228/240 frames → ❌FP
#     N6_C2_P3_V1_HB_3: 249/270 frames → ❌FP
#     N6_C2_P3_V2_HB_1: 199/270 frames → ❌FP
#     N6_C2_P3_V2_HB_3: 235/270 frames → ❌FP
#     N6_C2_P5_V1_HB_1: 26/270 frames → ❌FP
#     N6_C2_P5_V1_HB_2: 45/300 frames → ❌FP
#     N6_C2_P5_V2_HB_2: 63/300 frames → ❌FP
#     N6_C2_P5_V2_HB_3: 47/270 frames → ❌FP
#     N6_C2_P5_V3_HB_1: 25/270 frames → ❌FP
#     N6_C2_P5_V4_HB_1: 31/330 frames → ❌FP
#     N7_C1_P1_V1_HB_1: 0/225 frames → ✅TN
#     N7_C1_P2_V1_HB_2: 0/225 frames → ✅TN
#     N7_C1_P4_V1_HB_1: 59/175 frames → ❌FP
#     N7_C2_P3_V1_HB_1: 212/240 frames → ❌FP
#     N7_C2_P3_V2_HB_2: 225/240 frames → ❌FP
#     N7_C2_P5_V3_HB_2: 27/300 frames → ❌FP
#     N7_C2_P5_V4_HB_1: 80/300 frames → ❌FP
#     N8_C1_P1_V1_HB_1: 2/200 frames → ✅TN
#     N8_C1_P2_V1_HB_1: 0/225 frames → ✅TN
#     N8_C1_P2_V1_HB_4: 7/200 frames → ❌FP
#     N8_C1_P4_V1_HB_1: 60/175 frames → ❌FP
#     N8_C1_P4_V1_HB_3: 25/150 frames → ❌FP
#     N8_C2_P3_V1_HB_1: 281/300 frames → ❌FP
#     N8_C2_P3_V1_HB_4: 265/300 frames → ❌FP
#     N8_C2_P3_V2_HB_1: 189/270 frames → ❌FP
#     N8_C2_P3_V2_HB_3: 262/300 frames → ❌FP
#     N8_C2_P5_V1_HB_2: 21/330 frames → ❌FP
#     N8_C2_P5_V1_HB_3: 14/330 frames → ❌FP
#     N8_C2_P5_V2_HB_3: 21/330 frames → ❌FP
#     N8_C2_P5_V2_HB_4: 29/360 frames → ❌FP
#     N8_C2_P5_V3_HB_1: 31/420 frames → ❌FP
#     N8_C2_P5_V4_HB_1: 24/300 frames → ❌FP
#     N9_C1_P1_V1_HB_1: 3/225 frames → ✅TN
#     N9_C1_P2_V1_HB_1: 0/300 frames → ✅TN
#     N9_C1_P4_V1_HB_2: 21/175 frames → ❌FP
#     N9_C2_P3_V1_HB_2: 280/300 frames → ❌FP
#     N9_C2_P3_V2_HB_1: 305/360 frames → ❌FP
#     N9_C2_P5_V1_HB_2: 35/300 frames → ❌FP
#     N9_C2_P5_V2_HB_1: 5/330 frames → ❌FP
#     N9_C2_P5_V3_HB_1: 70/450 frames → ❌FP
#     N9_C2_P5_V4_HB_2: 25/330 frames → ❌FP
#
#   --- Métricas globales (clip-level) ---
#   Clips evaluados : 258 (140 pos / 118 neg)
#   Accuracy        : 0.5853
#   Precision       : 0.5753
#   Recall          : 0.9000
#   F1              : 0.7019
#
#   Matriz de confusión:
#                 Pred POS   Pred NEG
#   Real POS    |    126   |     14  |
#   Real NEG    |     93   |     25  |

# %% [markdown]
# ---
# ## 4. BLOQUE C — FP por categoría negativa

# %%
print('\n' + '='*60)
print('BLOQUE C — Falsos positivos por categoría (Modelo C)')
print('='*60)

neg_details = [d for d in clip_details if d['true'] == 0]
cat_stats   = defaultdict(lambda: {'total': 0, 'fp': 0})
for d in neg_details:
    cat = d['category']
    cat_stats[cat]['total'] += 1
    if d['pred'] == 1:
        cat_stats[cat]['fp'] += 1

# Comparativa con Modelo B
modelo_b_fp = {
    'N1':33.3,'N2':33.3,'N3':0.0,'N4':28.6,'N5':20.0,
    'N6':50.0,'N7':57.1,'N8':60.0,'N9':77.8,'N10':22.2,
    'N11':44.4,'N12':40.0
}

print(f"\n  {'Cat':<5} {'Descripción':<22} {'FP%_B':>7} {'FP%_C':>7} {'Δ':>7}")
print('  ' + '-'*55)
for cat in sorted(cat_stats, key=lambda x: int(x[1:])):
    s = cat_stats[cat]
    fp_c = s['fp'] / s['total'] * 100 if s['total'] > 0 else 0
    fp_b = modelo_b_fp.get(cat, 0)
    delta = fp_c - fp_b
    arrow = '↓' if delta < -5 else ('↑' if delta > 5 else '=')
    desc  = CAT_LABELS.get(cat, '')
    print(f"  {cat:<5} {desc:<22} {fp_b:>6.1f}% {fp_c:>6.1f}% {delta:>+6.1f}% {arrow}")
# Out:
# ============================================================
# BLOQUE C — Falsos positivos por categoría (Modelo C)
# ============================================================
#
#   Cat   Descripción              FP%_B   FP%_C       Δ
#   -------------------------------------------------------
#   N1    Walking empty hands      33.3%   77.8%  +44.5% ↑
#   N2    Jogging                  33.3%   77.8%  +44.5% ↑
#   N3    Running                   0.0%   75.0%  +75.0% ↑
#   N4    Sneaking empty hands     28.6%   71.4%  +42.8% ↑
#   N5    Phone relaxed            20.0%   90.0%  +70.0% ↑
#   N6    Phone looking            50.0%   81.2%  +31.2% ↑
#   N7    Phone both hands         57.1%   71.4%  +14.3% ↑
#   N8    Phone recording 1h       60.0%   86.7%  +26.7% ↑
#   N9    Phone recording 2h       77.8%   77.8%   -0.0% =
#   N10   Water bottle relaxed     22.2%   77.8%  +55.6% ↑
#   N11   Drinking                 44.4%   88.9%  +44.5% ↑
#   N12   Holding heavy object     40.0%   60.0%  +20.0% ↑

# %% [markdown]
# ---
# ## 5. Guardar resultados

# %%
import csv

# CSV de clips
csv_path = Path(OUT_DIR) / 'clip_results_modelo_c.csv'
with open(csv_path, 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['clip','true','pred','det_frames','total_frames','category'])
    writer.writeheader()
    writer.writerows(clip_details)

# TXT de métricas
txt_path = Path(OUT_DIR) / 'results_modelo_c.txt'
with open(txt_path, 'w') as f:
    f.write('=== EVALUACIÓN MODELO C (yolov8m-seg) ===\n\n')
    f.write(f'CONF_WEAPON={CONF_WEAPON} | THRESHOLD={DETECTION_THRESHOLD}\n\n')
    f.write(f'--- BLOQUE A ---\n')
    f.write(f'mAP@50    : {map50:.4f}\n')
    f.write(f'mAP@50:95 : {map5095:.4f}\n\n')
    f.write(f'--- BLOQUE B ---\n')
    f.write(f'Accuracy  : {accuracy:.4f}\n')
    f.write(f'Precision : {precision:.4f}\n')
    f.write(f'Recall    : {recall:.4f}\n')
    f.write(f'F1        : {f1:.4f}\n')
    f.write(f'TP={TP} TN={TN} FP={FP} FN={FN}\n\n')
    f.write('--- BLOQUE C ---\n')
    for cat in sorted(cat_stats, key=lambda x: int(x[1:])):
        s = cat_stats[cat]
        fp_rate = s['fp'] / s['total'] * 100 if s['total'] > 0 else 0
        f.write(f'  {cat}: {s["fp"]}/{s["total"]} ({fp_rate:.1f}%)\n')

print(f'✅ Resultados guardados en: {OUT_DIR}')

# Tabla comparativa final
print('\n' + '='*65)
print('TABLA COMPARATIVA FINAL — Modelo B vs Modelo C')
print('='*65)
print(f"  {'Config':<30} {'F1':>7} {'Prec':>7} {'Rec':>7} {'FP':>5} {'FN':>5}")
print('  ' + '-'*60)
print(f"  {'B — yolov8m (detección)':<30} {'0.7949':>7} {'0.7209':>7} {'0.8857':>7} {'48':>5} {'16':>5}")
print(f"  {'C — yolov8m-seg (segm.)':<30} {f1:>7.4f} {precision:>7.4f} {recall:>7.4f} {FP:>5} {FN:>5}")
print()

if f1 > 0.7949:
    print(f'  ✅ Modelo C MEJORA el F1 de Modelo B (+{(f1-0.7949)*100:.2f} pp)')
elif f1 > 0.7800:
    print(f'  ≈  Modelo C comparable a Modelo B (diferencia < 1.5 pp)')
else:
    print(f'  ❌ Modelo C no supera a Modelo B — documentar como resultado')

print('\n✅ Evaluación completa.')
# Out:
# ✅ Resultados guardados en: /content/drive/MyDrive/TFM/experiments/video_tests/GAR/runs/evaluation_modelo_d
#
# =================================================================
# TABLA COMPARATIVA FINAL — Modelo B vs Modelo C
# =================================================================
#   Config                              F1    Prec     Rec    FP    FN
#   ------------------------------------------------------------
#   B — yolov8m (detección)         0.7949  0.7209  0.8857    48    16
#   C — yolov8m-seg (segm.)         0.7019  0.5753  0.9000    93    14
#
#   ❌ Modelo C no supera a Modelo B — documentar como resultado
#
# ✅ Evaluación completa.
